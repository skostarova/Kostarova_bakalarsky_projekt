# %%
# OVERCONTACT - PREDIKCIA T2/T1 (POMER EFEKTIVNYCH TEPLOT)

# %%
# BLOK 1
# Importovanie kniznic.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ast import literal_eval

from keras.models import load_model
from sklearn.model_selection import train_test_split
from keras.layers import Conv1D, MaxPooling1D
from keras.layers import Input, Dense, LSTM, Dropout, Flatten
from keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
# BLOK 2
# Funkcie pre generovanie sumu. Nastavenie pseudo-nahodneho generatora.

def generate_observation_sigma(space_obs_frac=0.5):
    """
    Draws a standard deviation of noise in light curve points from a "true" value provided in synthetic light curve.
    Noise sigma is drawn from bimodal distribution taking into account contributions from space based and earth based
    observations which have different levels of stochastic noise.

    :param space_obs_frac: ratio between earth based and space based observations
    :return: float; standard deviation of the light curve noise
    """
    earth_based_sigma = 4e-3
    space_based_sigma = 2e-4
    sigma = np.random.choice([earth_based_sigma, space_based_sigma], p=[1-space_obs_frac, space_obs_frac])
    return np.random.rayleigh(sigma)

def stochastic_noise_generator(curve):
    """
    Introduces gaussian noise into synthetic observation provided in `curve`.

    :param curve: numpy.array; normalized light curve
    :return: Tuple(numpy.array, float); normalized light curve with added noise, standard deviation of observations
    """
    sigma = generate_observation_sigma()
    return np.random.normal(curve, sigma), np.full(curve.shape, sigma)

np.random.seed(1234)

# %%
# BLOK 3
# Nacitanie syntetickych dat.

data = pd.read_pickle("../overcontact_one_curve.pkl").reset_index()

# %%
# BLOK 4
# Vyber a priprava dat. Skontrolovanie vyberu podla filtrov.

data_sample=data.sample(n=100000)
data_sample["t2/t1"]=data_sample["secondary__t_eff"]/data["primary__t_eff"]

y=np.array(data_sample["t2/t1"])
X=[]
for row in data_sample["curve"]:
    X.append(row)
X=np.array(X)

print(data_sample["filter"].value_counts())
# Out:
# TESS         7877
# SLOAN_z      7796
# Bessell_R    7786
# Bessell_U    7782
# Bessell_I    7722
# SLOAN_g      7715
# SLOAN_r      7697
# SLOAN_u      7636
# Kepler       7627
# Bessell_V    7623
# Bessell_B    7583
# GaiaDR2      7583
# SLOAN_i      7573
# Name: filter, dtype: int64

# %%
# BLOK 5
# Rozdelenie dat na trenovaciu a testovaciu mnozinu v pomere 80:20. Pridanie umeleho sumu.

X_train1, X_test, y_train1, y_test = train_test_split(X, y, test_size=0.2)

X_train=[]
y_train=[]
for i in range(len(X_train1)):
    for j in range(3):
        curve=stochastic_noise_generator(X_train1[i])
        X_train.append(curve[0])
        y_train.append(y_train1[i])
        j+=1        
X_train=np.array(X_train)
y_train=np.array(y_train)

X_test_n=[]
y_test_n=[]
for i in range(len(X_test)):
    for j in range(3):
        curve=stochastic_noise_generator(X_test[i])
        X_test_n.append(curve[0])
        y_test_n.append(y_test[i])
        j+=1
X_test_n=np.array(X_test_n)
y_test_n=np.array(y_test_n)

# %%
# BLOK 6
# Vykreslenie grafov distribucie hodnot trenovacej a testovacej mnoziny

y1,y2=np.unique(y_test_n, return_counts=True)
y3,y4=np.unique(y_train, return_counts=True)
y12=pd.DataFrame(data={"value": y1, "count": y2})
y34=pd.DataFrame(data={"value": y3, "count": y4})

fig = plt.figure(figsize=(10,5))
plt.bar(y12["value"].array.astype(str), y12["count"], width=0.7)
plt.xticks(rotation=45, ha='right')
plt.title("Test data")
plt.xlabel("t2/t1")
plt.ylabel("count")
plt.grid(b="on")
plt.show()

fig = plt.figure(figsize=(10,5))
plt.bar(y34["value"].array.astype(str), y34["count"], width=0.7)
plt.xticks(rotation=45, ha='right')
plt.title("Train data")
plt.xlabel("t2/t1")
plt.ylabel("count")
plt.grid(b="on")
plt.show()

# %%
# BLOK 7
# Vytvorenie architektury modelu na predikciu t2/t1. Vypis architektury modelu. Nastavenia pre spustenie trenovania.

inputs = Input(shape=(400,1))
b = Conv1D(64, kernel_size = 3, padding = "valid")(inputs)
b = MaxPooling1D(2)(b)
b = Dropout(0.2)(b)
b = LSTM(64, return_sequences=True)(b)
b = Flatten()(b)
b = Dense(64, activation='relu')(b)
x = Dense(32, activation='relu')(b)
output = Dense(1, activation='linear')(x)
model = Model(inputs=inputs, outputs=output)
model.compile(loss='mse', optimizer='adam', metrics=["mae", "mape"])
print(model.summary())

saved_model = "overcontact_sT_pT.hdf5"
checkpoint = ModelCheckpoint(saved_model, monitor='val_mae', verbose=1, save_best_only=True, mode='min')
early = EarlyStopping(monitor="val_mae", mode="min", patience=25)
callbacks_list = [checkpoint, early]
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 400, 1)]          0
#
#  conv1d (Conv1D)             (None, 398, 64)           256
#
#  max_pooling1d (MaxPooling1D  (None, 199, 64)          0
#  )
#
#  dropout (Dropout)           (None, 199, 64)           0
#
#  lstm (LSTM)                 (None, 199, 64)           33024
#
#  flatten (Flatten)           (None, 12736)             0
#
#  dense (Dense)               (None, 64)                815168
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 850,561
# Trainable params: 850,561
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# BLOK 8
# Spustenie trenovania.

history=model.fit(X_train, y_train, validation_split=0.1, epochs=250, verbose=1, callbacks = callbacks_list, batch_size=64)
# Out:
# Epoch 1/250
# 3375/3375 [==============================] - ETA: 0s - loss: 0.0015 - mae: 0.0240 - mape: 2.5181
# Epoch 1: val_mae improved from inf to 0.01677, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 372s 109ms/step - loss: 0.0015 - mae: 0.0240 - mape: 2.5181 - val_loss: 4.6811e-04 - val_mae: 0.0168 - val_mape: 1.7691
# Epoch 2/250
# 3375/3375 [==============================] - ETA: 0s - loss: 5.7905e-04 - mae: 0.0191 - mape: 2.0051
# Epoch 2: val_mae did not improve from 0.01677
# 3375/3375 [==============================] - 369s 109ms/step - loss: 5.7905e-04 - mae: 0.0191 - mape: 2.0051 - val_loss: 5.7077e-04 - val_mae: 0.0190 - val_mape: 2.0126
# Epoch 3/250
# 3375/3375 [==============================] - ETA: 0s - loss: 5.1051e-04 - mae: 0.0180 - mape: 1.8839
# Epoch 3: val_mae improved from 0.01677 to 0.01544, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 370s 110ms/step - loss: 5.1051e-04 - mae: 0.0180 - mape: 1.8839 - val_loss: 3.8305e-04 - val_mae: 0.0154 - val_mape: 1.6161
# Epoch 4/250
# 3375/3375 [==============================] - ETA: 0s - loss: 4.2665e-04 - mae: 0.0164 - mape: 1.7168
# Epoch 4: val_mae did not improve from 0.01544
# 3375/3375 [==============================] - 371s 110ms/step - loss: 4.2665e-04 - mae: 0.0164 - mape: 1.7168 - val_loss: 3.8569e-04 - val_mae: 0.0159 - val_mape: 1.6508
# Epoch 5/250
# 3375/3375 [==============================] - ETA: 0s - loss: 4.0429e-04 - mae: 0.0159 - mape: 1.6652
# Epoch 5: val_mae did not improve from 0.01544
# 3375/3375 [==============================] - 371s 110ms/step - loss: 4.0429e-04 - mae: 0.0159 - mape: 1.6652 - val_loss: 4.1393e-04 - val_mae: 0.0167 - val_mape: 1.7349
# Epoch 6/250
# 3375/3375 [==============================] - ETA: 0s - loss: 3.8540e-04 - mae: 0.0155 - mape: 1.6221
# Epoch 6: val_mae improved from 0.01544 to 0.01455, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 371s 110ms/step - loss: 3.8540e-04 - mae: 0.0155 - mape: 1.6221 - val_loss: 3.5059e-04 - val_mae: 0.0146 - val_mape: 1.5237
# Epoch 7/250
# 3375/3375 [==============================] - ETA: 0s - loss: 3.6465e-04 - mae: 0.0150 - mape: 1.5750
# Epoch 7: val_mae improved from 0.01455 to 0.01331, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 371s 110ms/step - loss: 3.6465e-04 - mae: 0.0150 - mape: 1.5750 - val_loss: 3.0221e-04 - val_mae: 0.0133 - val_mape: 1.3998
# Epoch 8/250
# 3375/3375 [==============================] - ETA: 0s - loss: 3.4418e-04 - mae: 0.0146 - mape: 1.5296
# Epoch 8: val_mae did not improve from 0.01331
# 3375/3375 [==============================] - 371s 110ms/step - loss: 3.4418e-04 - mae: 0.0146 - mape: 1.5296 - val_loss: 3.1321e-04 - val_mae: 0.0136 - val_mape: 1.4372
# Epoch 9/250
# 3375/3375 [==============================] - ETA: 0s - loss: 3.2738e-04 - mae: 0.0141 - mape: 1.4850
# Epoch 9: val_mae did not improve from 0.01331
# 3375/3375 [==============================] - 372s 110ms/step - loss: 3.2738e-04 - mae: 0.0141 - mape: 1.4850 - val_loss: 3.1278e-04 - val_mae: 0.0133 - val_mape: 1.4118
# Epoch 10/250
# 3375/3375 [==============================] - ETA: 0s - loss: 3.1577e-04 - mae: 0.0138 - mape: 1.4532
# Epoch 10: val_mae improved from 0.01331 to 0.01267, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 372s 110ms/step - loss: 3.1577e-04 - mae: 0.0138 - mape: 1.4532 - val_loss: 2.7611e-04 - val_mae: 0.0127 - val_mape: 1.3334
# Epoch 11/250
# 3375/3375 [==============================] - ETA: 0s - loss: 3.0681e-04 - mae: 0.0136 - mape: 1.4292
# Epoch 11: val_mae improved from 0.01267 to 0.01238, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 372s 110ms/step - loss: 3.0681e-04 - mae: 0.0136 - mape: 1.4292 - val_loss: 2.6568e-04 - val_mae: 0.0124 - val_mape: 1.2987
# Epoch 12/250
# 3375/3375 [==============================] - ETA: 0s - loss: 3.0051e-04 - mae: 0.0134 - mape: 1.4118
# Epoch 12: val_mae did not improve from 0.01238
# 3375/3375 [==============================] - 372s 110ms/step - loss: 3.0051e-04 - mae: 0.0134 - mape: 1.4118 - val_loss: 3.3999e-04 - val_mae: 0.0152 - val_mape: 1.5863
# Epoch 13/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.9089e-04 - mae: 0.0131 - mape: 1.3802
# Epoch 13: val_mae did not improve from 0.01238
# 3375/3375 [==============================] - 372s 110ms/step - loss: 2.9089e-04 - mae: 0.0131 - mape: 1.3802 - val_loss: 2.9462e-04 - val_mae: 0.0128 - val_mape: 1.3511
# Epoch 14/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.8625e-04 - mae: 0.0130 - mape: 1.3633
# Epoch 14: val_mae improved from 0.01238 to 0.01187, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 372s 110ms/step - loss: 2.8625e-04 - mae: 0.0130 - mape: 1.3633 - val_loss: 2.5843e-04 - val_mae: 0.0119 - val_mape: 1.2498
# Epoch 15/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.8403e-04 - mae: 0.0129 - mape: 1.3557
# Epoch 15: val_mae did not improve from 0.01187
# 3375/3375 [==============================] - 372s 110ms/step - loss: 2.8403e-04 - mae: 0.0129 - mape: 1.3557 - val_loss: 2.6677e-04 - val_mae: 0.0120 - val_mape: 1.2575
# Epoch 16/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.8077e-04 - mae: 0.0128 - mape: 1.3465
# Epoch 16: val_mae improved from 0.01187 to 0.01175, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 372s 110ms/step - loss: 2.8077e-04 - mae: 0.0128 - mape: 1.3465 - val_loss: 2.6956e-04 - val_mae: 0.0117 - val_mape: 1.2416
# Epoch 17/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.7737e-04 - mae: 0.0127 - mape: 1.3378
# Epoch 17: val_mae improved from 0.01175 to 0.01158, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 373s 110ms/step - loss: 2.7737e-04 - mae: 0.0127 - mape: 1.3378 - val_loss: 2.5262e-04 - val_mae: 0.0116 - val_mape: 1.2201
# Epoch 18/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.7495e-04 - mae: 0.0126 - mape: 1.3278
# Epoch 18: val_mae did not improve from 0.01158
# 3375/3375 [==============================] - 372s 110ms/step - loss: 2.7495e-04 - mae: 0.0126 - mape: 1.3278 - val_loss: 2.3940e-04 - val_mae: 0.0117 - val_mape: 1.2336
# Epoch 19/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.7191e-04 - mae: 0.0125 - mape: 1.3179
# Epoch 19: val_mae did not improve from 0.01158
# 3375/3375 [==============================] - 372s 110ms/step - loss: 2.7191e-04 - mae: 0.0125 - mape: 1.3179 - val_loss: 2.4378e-04 - val_mae: 0.0118 - val_mape: 1.2372
# Epoch 20/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.7209e-04 - mae: 0.0125 - mape: 1.3182
# Epoch 20: val_mae did not improve from 0.01158
# 3375/3375 [==============================] - 372s 110ms/step - loss: 2.7209e-04 - mae: 0.0125 - mape: 1.3182 - val_loss: 2.9013e-04 - val_mae: 0.0137 - val_mape: 1.4231
# Epoch 21/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.6840e-04 - mae: 0.0124 - mape: 1.3019
# Epoch 21: val_mae improved from 0.01158 to 0.01156, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 373s 110ms/step - loss: 2.6840e-04 - mae: 0.0124 - mape: 1.3019 - val_loss: 2.3798e-04 - val_mae: 0.0116 - val_mape: 1.2127
# Epoch 22/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.6622e-04 - mae: 0.0123 - mape: 1.2917
# Epoch 22: val_mae improved from 0.01156 to 0.01147, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 372s 110ms/step - loss: 2.6622e-04 - mae: 0.0123 - mape: 1.2917 - val_loss: 2.4353e-04 - val_mae: 0.0115 - val_mape: 1.2081
# Epoch 23/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.6367e-04 - mae: 0.0122 - mape: 1.2820
# Epoch 23: val_mae improved from 0.01147 to 0.01142, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 372s 110ms/step - loss: 2.6367e-04 - mae: 0.0122 - mape: 1.2820 - val_loss: 2.3861e-04 - val_mae: 0.0114 - val_mape: 1.1997
# Epoch 24/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.6294e-04 - mae: 0.0122 - mape: 1.2803
# Epoch 24: val_mae did not improve from 0.01142
# 3375/3375 [==============================] - 372s 110ms/step - loss: 2.6294e-04 - mae: 0.0122 - mape: 1.2803 - val_loss: 2.3347e-04 - val_mae: 0.0115 - val_mape: 1.2120
# Epoch 25/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.5943e-04 - mae: 0.0121 - mape: 1.2670
# Epoch 25: val_mae did not improve from 0.01142
# 3375/3375 [==============================] - 373s 110ms/step - loss: 2.5943e-04 - mae: 0.0121 - mape: 1.2670 - val_loss: 2.7354e-04 - val_mae: 0.0121 - val_mape: 1.2833
# Epoch 26/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.5741e-04 - mae: 0.0120 - mape: 1.2632
# Epoch 26: val_mae improved from 0.01142 to 0.01084, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 373s 110ms/step - loss: 2.5741e-04 - mae: 0.0120 - mape: 1.2632 - val_loss: 2.2288e-04 - val_mae: 0.0108 - val_mape: 1.1397
# Epoch 27/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.5711e-04 - mae: 0.0120 - mape: 1.2622
# Epoch 27: val_mae did not improve from 0.01084
# 3375/3375 [==============================] - 372s 110ms/step - loss: 2.5711e-04 - mae: 0.0120 - mape: 1.2622 - val_loss: 2.5518e-04 - val_mae: 0.0114 - val_mape: 1.2064
# Epoch 28/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.5327e-04 - mae: 0.0119 - mape: 1.2516
# Epoch 28: val_mae did not improve from 0.01084
# 3375/3375 [==============================] - 372s 110ms/step - loss: 2.5327e-04 - mae: 0.0119 - mape: 1.2516 - val_loss: 2.2889e-04 - val_mae: 0.0111 - val_mape: 1.1730
# Epoch 29/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.5254e-04 - mae: 0.0119 - mape: 1.2486
# Epoch 29: val_mae did not improve from 0.01084
# 3375/3375 [==============================] - 373s 110ms/step - loss: 2.5254e-04 - mae: 0.0119 - mape: 1.2486 - val_loss: 2.2473e-04 - val_mae: 0.0112 - val_mape: 1.1811
# Epoch 30/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.5216e-04 - mae: 0.0119 - mape: 1.2482
# Epoch 30: val_mae did not improve from 0.01084
# 3375/3375 [==============================] - 373s 110ms/step - loss: 2.5216e-04 - mae: 0.0119 - mape: 1.2482 - val_loss: 2.4522e-04 - val_mae: 0.0123 - val_mape: 1.2867
# Epoch 31/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.5113e-04 - mae: 0.0118 - mape: 1.2441
# Epoch 31: val_mae did not improve from 0.01084
# 3375/3375 [==============================] - 373s 110ms/step - loss: 2.5113e-04 - mae: 0.0118 - mape: 1.2441 - val_loss: 2.2630e-04 - val_mae: 0.0112 - val_mape: 1.1814
# Epoch 32/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.5004e-04 - mae: 0.0118 - mape: 1.2399
# Epoch 32: val_mae did not improve from 0.01084
# 3375/3375 [==============================] - 373s 110ms/step - loss: 2.5004e-04 - mae: 0.0118 - mape: 1.2399 - val_loss: 2.5574e-04 - val_mae: 0.0124 - val_mape: 1.2970
# Epoch 33/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.4817e-04 - mae: 0.0118 - mape: 1.2358
# Epoch 33: val_mae did not improve from 0.01084
# 3375/3375 [==============================] - 373s 111ms/step - loss: 2.4817e-04 - mae: 0.0118 - mape: 1.2358 - val_loss: 2.1470e-04 - val_mae: 0.0110 - val_mape: 1.1574
# Epoch 34/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.4780e-04 - mae: 0.0117 - mape: 1.2347
# Epoch 34: val_mae did not improve from 0.01084
# 3375/3375 [==============================] - 373s 110ms/step - loss: 2.4780e-04 - mae: 0.0117 - mape: 1.2347 - val_loss: 3.2683e-04 - val_mae: 0.0151 - val_mape: 1.5656
# Epoch 35/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.4590e-04 - mae: 0.0117 - mape: 1.2284
# Epoch 35: val_mae did not improve from 0.01084
# 3375/3375 [==============================] - 373s 111ms/step - loss: 2.4590e-04 - mae: 0.0117 - mape: 1.2284 - val_loss: 2.1735e-04 - val_mae: 0.0109 - val_mape: 1.1421
# Epoch 36/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.4488e-04 - mae: 0.0117 - mape: 1.2250
# Epoch 36: val_mae improved from 0.01084 to 0.01055, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 373s 110ms/step - loss: 2.4488e-04 - mae: 0.0117 - mape: 1.2250 - val_loss: 2.1597e-04 - val_mae: 0.0105 - val_mape: 1.1134
# Epoch 37/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.4502e-04 - mae: 0.0117 - mape: 1.2264
# Epoch 37: val_mae did not improve from 0.01055
# 3375/3375 [==============================] - 372s 110ms/step - loss: 2.4502e-04 - mae: 0.0117 - mape: 1.2264 - val_loss: 2.3070e-04 - val_mae: 0.0109 - val_mape: 1.1493
# Epoch 38/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.4323e-04 - mae: 0.0116 - mape: 1.2215
# Epoch 38: val_mae did not improve from 0.01055
# 3375/3375 [==============================] - 373s 110ms/step - loss: 2.4323e-04 - mae: 0.0116 - mape: 1.2215 - val_loss: 2.3365e-04 - val_mae: 0.0116 - val_mape: 1.2103
# Epoch 39/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.4436e-04 - mae: 0.0116 - mape: 1.2242
# Epoch 39: val_mae improved from 0.01055 to 0.01035, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 373s 110ms/step - loss: 2.4436e-04 - mae: 0.0116 - mape: 1.2242 - val_loss: 2.1153e-04 - val_mae: 0.0104 - val_mape: 1.0919
# Epoch 40/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.4404e-04 - mae: 0.0116 - mape: 1.2243
# Epoch 40: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 372s 110ms/step - loss: 2.4404e-04 - mae: 0.0116 - mape: 1.2243 - val_loss: 2.2238e-04 - val_mae: 0.0113 - val_mape: 1.1843
# Epoch 41/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.4210e-04 - mae: 0.0116 - mape: 1.2177
# Epoch 41: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 110ms/step - loss: 2.4210e-04 - mae: 0.0116 - mape: 1.2177 - val_loss: 2.1328e-04 - val_mae: 0.0106 - val_mape: 1.1191
# Epoch 42/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.4255e-04 - mae: 0.0116 - mape: 1.2196
# Epoch 42: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 111ms/step - loss: 2.4255e-04 - mae: 0.0116 - mape: 1.2196 - val_loss: 2.3705e-04 - val_mae: 0.0118 - val_mape: 1.2305
# Epoch 43/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.4144e-04 - mae: 0.0116 - mape: 1.2158
# Epoch 43: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 111ms/step - loss: 2.4144e-04 - mae: 0.0116 - mape: 1.2158 - val_loss: 2.1222e-04 - val_mae: 0.0107 - val_mape: 1.1222
# Epoch 44/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.4058e-04 - mae: 0.0116 - mape: 1.2147
# Epoch 44: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 111ms/step - loss: 2.4058e-04 - mae: 0.0116 - mape: 1.2147 - val_loss: 2.1853e-04 - val_mae: 0.0109 - val_mape: 1.1451
# Epoch 45/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.4029e-04 - mae: 0.0115 - mape: 1.2126
# Epoch 45: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 110ms/step - loss: 2.4029e-04 - mae: 0.0115 - mape: 1.2126 - val_loss: 2.1518e-04 - val_mae: 0.0108 - val_mape: 1.1366
# Epoch 46/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3884e-04 - mae: 0.0115 - mape: 1.2078
# Epoch 46: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 110ms/step - loss: 2.3884e-04 - mae: 0.0115 - mape: 1.2078 - val_loss: 2.1185e-04 - val_mae: 0.0104 - val_mape: 1.0989
# Epoch 47/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3799e-04 - mae: 0.0115 - mape: 1.2045
# Epoch 47: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 110ms/step - loss: 2.3799e-04 - mae: 0.0115 - mape: 1.2045 - val_loss: 2.0892e-04 - val_mae: 0.0107 - val_mape: 1.1261
# Epoch 48/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3827e-04 - mae: 0.0115 - mape: 1.2057
# Epoch 48: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 111ms/step - loss: 2.3827e-04 - mae: 0.0115 - mape: 1.2057 - val_loss: 2.1209e-04 - val_mae: 0.0107 - val_mape: 1.1248
# Epoch 49/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3637e-04 - mae: 0.0114 - mape: 1.1989
# Epoch 49: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 111ms/step - loss: 2.3637e-04 - mae: 0.0114 - mape: 1.1989 - val_loss: 2.1073e-04 - val_mae: 0.0107 - val_mape: 1.1216
# Epoch 50/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3703e-04 - mae: 0.0114 - mape: 1.2010
# Epoch 50: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 111ms/step - loss: 2.3703e-04 - mae: 0.0114 - mape: 1.2010 - val_loss: 2.0956e-04 - val_mae: 0.0106 - val_mape: 1.1107
# Epoch 51/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3687e-04 - mae: 0.0114 - mape: 1.2020
# Epoch 51: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 111ms/step - loss: 2.3687e-04 - mae: 0.0114 - mape: 1.2020 - val_loss: 2.1071e-04 - val_mae: 0.0106 - val_mape: 1.1173
# Epoch 52/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3583e-04 - mae: 0.0114 - mape: 1.1977
# Epoch 52: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 111ms/step - loss: 2.3583e-04 - mae: 0.0114 - mape: 1.1977 - val_loss: 2.3153e-04 - val_mae: 0.0110 - val_mape: 1.1602
# Epoch 53/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3565e-04 - mae: 0.0114 - mape: 1.1962
# Epoch 53: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 111ms/step - loss: 2.3565e-04 - mae: 0.0114 - mape: 1.1962 - val_loss: 2.4918e-04 - val_mae: 0.0123 - val_mape: 1.2868
# Epoch 54/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3607e-04 - mae: 0.0114 - mape: 1.1987
# Epoch 54: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 111ms/step - loss: 2.3607e-04 - mae: 0.0114 - mape: 1.1987 - val_loss: 2.2605e-04 - val_mae: 0.0116 - val_mape: 1.2093
# Epoch 55/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3463e-04 - mae: 0.0114 - mape: 1.1950
# Epoch 55: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 111ms/step - loss: 2.3463e-04 - mae: 0.0114 - mape: 1.1950 - val_loss: 2.1978e-04 - val_mae: 0.0108 - val_mape: 1.1393
# Epoch 56/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3460e-04 - mae: 0.0114 - mape: 1.1941
# Epoch 56: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 111ms/step - loss: 2.3460e-04 - mae: 0.0114 - mape: 1.1941 - val_loss: 2.1696e-04 - val_mae: 0.0107 - val_mape: 1.1250
# Epoch 57/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3481e-04 - mae: 0.0114 - mape: 1.1938
# Epoch 57: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 373s 111ms/step - loss: 2.3481e-04 - mae: 0.0114 - mape: 1.1938 - val_loss: 2.1741e-04 - val_mae: 0.0109 - val_mape: 1.1473
# Epoch 58/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3472e-04 - mae: 0.0113 - mape: 1.1932
# Epoch 58: val_mae did not improve from 0.01035
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.3472e-04 - mae: 0.0113 - mape: 1.1932 - val_loss: 2.1285e-04 - val_mae: 0.0106 - val_mape: 1.1207
# Epoch 59/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3369e-04 - mae: 0.0113 - mape: 1.1904
# Epoch 59: val_mae improved from 0.01035 to 0.01035, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.3369e-04 - mae: 0.0113 - mape: 1.1904 - val_loss: 2.1142e-04 - val_mae: 0.0103 - val_mape: 1.0896
# Epoch 60/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3180e-04 - mae: 0.0113 - mape: 1.1837
# Epoch 60: val_mae improved from 0.01035 to 0.01020, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.3180e-04 - mae: 0.0113 - mape: 1.1837 - val_loss: 2.0259e-04 - val_mae: 0.0102 - val_mape: 1.0724
# Epoch 61/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3277e-04 - mae: 0.0113 - mape: 1.1887
# Epoch 61: val_mae improved from 0.01020 to 0.01002, saving model to overcontact_sT_pT.hdf5
# 3375/3375 [==============================] - 375s 111ms/step - loss: 2.3277e-04 - mae: 0.0113 - mape: 1.1887 - val_loss: 2.0083e-04 - val_mae: 0.0100 - val_mape: 1.0563
# Epoch 62/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3132e-04 - mae: 0.0113 - mape: 1.1831
# Epoch 62: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.3132e-04 - mae: 0.0113 - mape: 1.1831 - val_loss: 2.1217e-04 - val_mae: 0.0104 - val_mape: 1.0917
# Epoch 63/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3203e-04 - mae: 0.0113 - mape: 1.1860
# Epoch 63: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.3203e-04 - mae: 0.0113 - mape: 1.1860 - val_loss: 2.0348e-04 - val_mae: 0.0102 - val_mape: 1.0726
# Epoch 64/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3070e-04 - mae: 0.0112 - mape: 1.1804
# Epoch 64: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.3070e-04 - mae: 0.0112 - mape: 1.1804 - val_loss: 2.1879e-04 - val_mae: 0.0110 - val_mape: 1.1558
# Epoch 65/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3139e-04 - mae: 0.0113 - mape: 1.1829
# Epoch 65: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.3139e-04 - mae: 0.0113 - mape: 1.1829 - val_loss: 2.0219e-04 - val_mae: 0.0102 - val_mape: 1.0720
# Epoch 66/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3044e-04 - mae: 0.0112 - mape: 1.1804
# Epoch 66: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.3044e-04 - mae: 0.0112 - mape: 1.1804 - val_loss: 2.1421e-04 - val_mae: 0.0109 - val_mape: 1.1373
# Epoch 67/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3111e-04 - mae: 0.0112 - mape: 1.1821
# Epoch 67: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.3111e-04 - mae: 0.0112 - mape: 1.1821 - val_loss: 2.1495e-04 - val_mae: 0.0105 - val_mape: 1.1001
# Epoch 68/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.2994e-04 - mae: 0.0112 - mape: 1.1797
# Epoch 68: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.2994e-04 - mae: 0.0112 - mape: 1.1797 - val_loss: 2.3748e-04 - val_mae: 0.0112 - val_mape: 1.1834
# Epoch 69/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3023e-04 - mae: 0.0112 - mape: 1.1798
# Epoch 69: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.3023e-04 - mae: 0.0112 - mape: 1.1798 - val_loss: 2.1253e-04 - val_mae: 0.0106 - val_mape: 1.1118
# Epoch 70/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.2860e-04 - mae: 0.0112 - mape: 1.1735
# Epoch 70: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.2860e-04 - mae: 0.0112 - mape: 1.1735 - val_loss: 2.3900e-04 - val_mae: 0.0121 - val_mape: 1.2613
# Epoch 71/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3048e-04 - mae: 0.0112 - mape: 1.1795
# Epoch 71: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.3048e-04 - mae: 0.0112 - mape: 1.1795 - val_loss: 2.0277e-04 - val_mae: 0.0104 - val_mape: 1.0892
# Epoch 72/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.3041e-04 - mae: 0.0112 - mape: 1.1785
# Epoch 72: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.3041e-04 - mae: 0.0112 - mape: 1.1785 - val_loss: 2.1962e-04 - val_mae: 0.0106 - val_mape: 1.1267
# Epoch 73/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.2861e-04 - mae: 0.0111 - mape: 1.1720
# Epoch 73: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.2861e-04 - mae: 0.0111 - mape: 1.1720 - val_loss: 2.0855e-04 - val_mae: 0.0108 - val_mape: 1.1354
# Epoch 74/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.2734e-04 - mae: 0.0111 - mape: 1.1700
# Epoch 74: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.2734e-04 - mae: 0.0111 - mape: 1.1700 - val_loss: 2.0962e-04 - val_mae: 0.0107 - val_mape: 1.1253
# Epoch 75/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.2876e-04 - mae: 0.0112 - mape: 1.1754
# Epoch 75: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 375s 111ms/step - loss: 2.2876e-04 - mae: 0.0112 - mape: 1.1754 - val_loss: 1.9892e-04 - val_mae: 0.0104 - val_mape: 1.0922
# Epoch 76/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.2749e-04 - mae: 0.0111 - mape: 1.1703
# Epoch 76: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.2749e-04 - mae: 0.0111 - mape: 1.1703 - val_loss: 2.0824e-04 - val_mae: 0.0105 - val_mape: 1.1046
# Epoch 77/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.2825e-04 - mae: 0.0111 - mape: 1.1723
# Epoch 77: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.2825e-04 - mae: 0.0111 - mape: 1.1723 - val_loss: 2.0679e-04 - val_mae: 0.0102 - val_mape: 1.0776
# Epoch 78/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.2786e-04 - mae: 0.0111 - mape: 1.1701
# Epoch 78: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.2786e-04 - mae: 0.0111 - mape: 1.1701 - val_loss: 1.9898e-04 - val_mae: 0.0101 - val_mape: 1.0684
# Epoch 79/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.2702e-04 - mae: 0.0111 - mape: 1.1668
# Epoch 79: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 375s 111ms/step - loss: 2.2702e-04 - mae: 0.0111 - mape: 1.1668 - val_loss: 2.2891e-04 - val_mae: 0.0115 - val_mape: 1.2041
# Epoch 80/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.2756e-04 - mae: 0.0111 - mape: 1.1708
# Epoch 80: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 375s 111ms/step - loss: 2.2756e-04 - mae: 0.0111 - mape: 1.1708 - val_loss: 2.0081e-04 - val_mae: 0.0102 - val_mape: 1.0781
# Epoch 81/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.2684e-04 - mae: 0.0111 - mape: 1.1681
# Epoch 81: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.2684e-04 - mae: 0.0111 - mape: 1.1681 - val_loss: 2.0591e-04 - val_mae: 0.0105 - val_mape: 1.1030
# Epoch 82/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.2620e-04 - mae: 0.0111 - mape: 1.1660
# Epoch 82: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.2620e-04 - mae: 0.0111 - mape: 1.1660 - val_loss: 2.0747e-04 - val_mae: 0.0104 - val_mape: 1.0993
# Epoch 83/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.2720e-04 - mae: 0.0111 - mape: 1.1703
# Epoch 83: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 375s 111ms/step - loss: 2.2720e-04 - mae: 0.0111 - mape: 1.1703 - val_loss: 2.2160e-04 - val_mae: 0.0107 - val_mape: 1.1256
# Epoch 84/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.2507e-04 - mae: 0.0110 - mape: 1.1610
# Epoch 84: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 375s 111ms/step - loss: 2.2507e-04 - mae: 0.0110 - mape: 1.1610 - val_loss: 2.1015e-04 - val_mae: 0.0105 - val_mape: 1.1061
# Epoch 85/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.2520e-04 - mae: 0.0111 - mape: 1.1635
# Epoch 85: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 374s 111ms/step - loss: 2.2520e-04 - mae: 0.0111 - mape: 1.1635 - val_loss: 2.1874e-04 - val_mae: 0.0107 - val_mape: 1.1283
# Epoch 86/250
# 3375/3375 [==============================] - ETA: 0s - loss: 2.2569e-04 - mae: 0.0111 - mape: 1.1636
# Epoch 86: val_mae did not improve from 0.01002
# 3375/3375 [==============================] - 375s 111ms/step - loss: 2.2569e-04 - mae: 0.0111 - mape: 1.1636 - val_loss: 1.9719e-04 - val_mae: 0.0101 - val_mape: 1.0624

# %%
# BLOK 9
# Nacitanie a vyhodnotenie modelu na testovacich datach.

model=load_model("../finalne ntb/overcontact_sT_pT.hdf5")
model.evaluate(X_test_n, y_test_n)
# Out:
# 1875/1875 [==============================] - 59s 31ms/step - loss: 1.9691e-04 - mae: 0.0099 - mape: 1.0429
# [0.00019690759654622525, 0.009887095540761948, 1.0429342985153198]

# %%
# BLOK 10
# Vysledky predikcie na testovacich krivkach.

y_pred_n=model.predict(X_test_n)
y_pred_n=np.reshape(y_pred_n, len(y_pred_n))
df_n=pd.DataFrame(data={'y_test_n': y_test_n, 'y_predict_n': y_pred_n})
df_n["diff"]=df_n["y_test_n"]-df_n["y_predict_n"]
df_n["abs_diff"]=abs(df_n["diff"])
df_n["re"]=df_n["abs_diff"]/df_n["y_test_n"]

print("pocet kriviek s relativnou chybou < 5%: " + str(len(df_n[df_n["re"]<0.05])) +
      "\npocet kriviek s relativnou chybou < 2,5%: " + str(len(df_n[df_n["re"]<0.025])) +
      "\npocet kriviek s relativnou chybou < 1%: " + str(len(df_n[df_n["re"]<0.01])))
# Out:
# pocet kriviek s relativnou chybou < 5%: 59393
# pocet kriviek s relativnou chybou < 2,5%: 54599
# pocet kriviek s relativnou chybou < 1%: 36464

# %%
# BLOK 11
# Graficke znazornenie priemernych relativnych chyb podla jednotlivych hodnot pomerov.

df_mean=df_n.groupby(["y_test_n"])
df_mean=pd.DataFrame(df_mean.re.mean()).reset_index()
a_n=df_mean.y_test_n.array.astype(str)
b_n=df_mean.re.array

fig = plt.figure(figsize=(10,5))
ax = fig.add_axes([0,0,1,1])
true = a_n
mean = b_n
ax.bar(true, mean)
ax.set_ylabel("MAPE")
ax.set_xlabel("true t2/t1")
ax.set_title("Mean Absolute Percentage Error vs. True t2/t1")
plt.xticks(rotation=45, ha='right')
plt.grid(b="on")

plt.show()

# %%
# BLOK 12
# Nacitanie a priprava observacnych dat.

obs=pd.read_csv("observed.csv")
obs["t2/t1"]=obs["T2"]/obs["T1"]
obs=obs[["name", "filter", "Spot", "t2/t1", "curve", "Type"]]
obs=obs.loc[obs.Type.isin(["contact", "overcontact"])]
X_o=[]
for row in obs["curve"]:
    processed_data=literal_eval(row)
    X_o.append(processed_data)
X_o=np.array(X_o, dtype=np.float32)

# %%
# BLOK 13
# Predikcia a zhodnotenie modelu na observacnych datach.

obs_pred=model.predict(X_o)
model.evaluate(X_o,obs["t2/t1"])
# Out:
# 2/2 [==============================] - 1s 24ms/step - loss: 0.0068 - mae: 0.0551 - mape: 6.3025
# [0.00684985239058733, 0.055129796266555786, 6.302466869354248]

# %%
# BLOK 14
# Vysledky predikcie na observacnych krivkach.

y_pred_o=np.reshape(obs_pred, len(obs_pred))
df_o = {"validation": obs["t2/t1"], "predict": y_pred_o, "name": obs["name"], "filter": obs["filter"], "spot": obs["Spot"]}
df_o = pd.DataFrame(data=df_o)
df_o["diff"]=df_o["validation"]-df_o["predict"]
df_o["abs_diff"]=abs(df_o["diff"])
df_o["re"]=df_o["abs_diff"]/df_o["validation"]

print("pocet observacnych kriviek s relativnou chybou < 5%: " + str(len(df_o[df_o["re"]<0.05])) +
      "\npocet observacnych kriviek s relativnou chybou < 2,5%: " + str(len(df_o[df_o["re"]<0.025])) +
      "\npocet observacnych kriviek s relativnou chybou < 1%: " + str(len(df_o[df_o["re"]<0.01])))
# Out:
# pocet observacnych kriviek s relativnou chybou < 5%: 32
# pocet observacnych kriviek s relativnou chybou < 2,5%: 16
# pocet observacnych kriviek s relativnou chybou < 1%: 6

# %%
# BLOK 15
# 

def autolabel(rects, pos):
    n=0
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2. +0.23 , pos,
                s=spot.spot[n],
                ha='center', va='bottom', fontsize=12, bbox=dict(facecolor='yellow', alpha=0.5))
        n=n+1
spot=df_o[["name", "spot"]].drop_duplicates().reset_index()
spot.spot=spot.spot.map({"N":"", "Y":"SPOT", "y":"SPOT"})
true_t2_t1=df_o[["validation", "name"]].groupby(["name"]).mean()
names=pd.DataFrame(data={"name":true_t2_t1.index})                #názvy systémov hviezd
t2_t1_B=pd.merge(names, df_o[df_o["filter"]=="B"][["predict", "name"]], how="left")
t2_t1_V=pd.merge(names, df_o[df_o["filter"]=="V"][["predict", "name"]], how="left")
t2_t1_R=pd.merge(names, df_o[df_o["filter"]=="R"][["predict", "name"]], how="left")
t2_t1_I=pd.merge(names, df_o[df_o["filter"]=="I"][["predict", "name"]], how="left")

fig, ax = plt.subplots(figsize=(20,7))

barWidth = 0.12
br1 = np.arange(len(names))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
br5 = [x + barWidth for x in br4]

r=ax.bar(br1, true_t2_t1.validation, barWidth, label='true t2/t1', color="limegreen")
ax.bar(br2, t2_t1_V.predict, barWidth, label='prediction on filter V', color="moccasin")
ax.bar(br3, t2_t1_B.predict, barWidth, label='prediction on filter B', color="cornflowerblue")
ax.bar(br4, t2_t1_I.predict, barWidth, label='prediction on filter I', color="silver")
ax.bar(br5, t2_t1_R.predict, barWidth, label='prediction on filter R', color="salmon")

plt.title("T2/T1 predictions - overcontact")
plt.xticks(br1, true_t2_t1.index, rotation=45, ha='right')
plt.ylabel("t2/t1")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.grid(b="on")
plt.ylim(top=1.16)
autolabel(r, 1.1)
plt.show()
